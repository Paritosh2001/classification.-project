# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

# %%
class_names = ['abstract triangle pattern', 'memphis  pattern', 'space pattern', 'terrazoo pattern']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['C:/project 22/train', 'C:/project 22/test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#  16%|█▌        | 7/44 [00:00<00:00, 64.71it/s]
# Loading C:/project 22/train
# 100%|██████████| 44/44 [00:00<00:00, 44.17it/s]
# 100%|██████████| 44/44 [00:00<00:00, 46.70it/s]
# 100%|██████████| 44/44 [00:01<00:00, 32.04it/s]
# 100%|██████████| 44/44 [00:01<00:00, 33.55it/s]
#  38%|███▊      | 6/16 [00:00<00:00, 49.58it/s]
# Loading C:/project 22/test
# 100%|██████████| 16/16 [00:00<00:00, 51.99it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34.66it/s]
# 100%|██████████| 16/16 [00:00<00:00, 29.08it/s]
# 100%|██████████| 16/16 [00:00<00:00, 38.60it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 176
# Number of testing examples: 64
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
def display_random_image(class_names, images, labels):
   
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
  
    
    fig = plt.figure(figsize=(20,20))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=20, validation_split = 0.2)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
train_loss, train_acc = model.evaluate(train_images, train_labels, verbose=2)
print("Test accuracy: ", test_acc)
print("train accuracy: ", train_acc)
model.save("model.h5")
# Out:
# Train on 140 samples, validate on 36 samples
# Epoch 1/20
# 140/140 [==============================] - 13s 95ms/sample - loss: 1.7944 - accuracy: 0.2857 - val_loss: 6.6589 - val_accuracy: 0.0833
# Epoch 2/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 4.8456 - accuracy: 0.2714 - val_loss: 2.6708 - val_accuracy: 0.2778
# Epoch 3/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 2.9868 - accuracy: 0.2429 - val_loss: 1.6986 - val_accuracy: 0.2222
# Epoch 4/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 1.5219 - accuracy: 0.2857 - val_loss: 1.4860 - val_accuracy: 0.1944
# Epoch 5/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 1.1259 - accuracy: 0.5500 - val_loss: 1.5873 - val_accuracy: 0.1111
# Epoch 6/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 1.1591 - accuracy: 0.4500 - val_loss: 1.7147 - val_accuracy: 0.2222
# Epoch 7/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 1.1914 - accuracy: 0.4286 - val_loss: 1.7205 - val_accuracy: 0.2778
# Epoch 8/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 1.1646 - accuracy: 0.4000 - val_loss: 1.5750 - val_accuracy: 0.2222
# Epoch 9/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 1.0707 - accuracy: 0.5357 - val_loss: 1.3989 - val_accuracy: 0.4722
# Epoch 10/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.9620 - accuracy: 0.7714 - val_loss: 1.2601 - val_accuracy: 0.5278
# Epoch 11/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.8398 - accuracy: 0.7500 - val_loss: 1.3325 - val_accuracy: 0.3889
# Epoch 12/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.7183 - accuracy: 0.8143 - val_loss: 1.7402 - val_accuracy: 0.2778
# Epoch 13/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.6961 - accuracy: 0.6714 - val_loss: 1.7426 - val_accuracy: 0.3889
# Epoch 14/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.6043 - accuracy: 0.7857 - val_loss: 1.4740 - val_accuracy: 0.5000
# Epoch 15/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.5517 - accuracy: 0.8143 - val_loss: 1.5693 - val_accuracy: 0.4444
# Epoch 16/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.5706 - accuracy: 0.7714 - val_loss: 1.7495 - val_accuracy: 0.5000
# Epoch 17/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.4553 - accuracy: 0.8429 - val_loss: 1.7473 - val_accuracy: 0.4722
# Epoch 18/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.4012 - accuracy: 0.8929 - val_loss: 1.3835 - val_accuracy: 0.4722
# Epoch 19/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.3652 - accuracy: 0.9143 - val_loss: 1.2477 - val_accuracy: 0.5000
# Epoch 20/20
# 140/140 [==============================] - 0s 3ms/sample - loss: 0.3190 - accuracy: 0.9071 - val_loss: 1.4773 - val_accuracy: 0.4722
# 64/64 - 1s - loss: 1.2728 - accuracy: 0.5312
# 176/176 - 1s - loss: 0.5390 - accuracy: 0.8182
# Test accuracy:  0.53125
# train accuracy:  0.8181818

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 64/64 [==============================] - 0s 3ms/sample - loss: 1.2728 - accuracy: 0.5312

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 5,319,462
# Trainable params: 5,319,462
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
img_path="C:/project 22/test/space pattern/210.png"

# %%
img = image.load_img(img_path,target_size=(200,200))
img= image.img_to_array(img)
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
x = img/255
plt.imshow(x)
plt.axis('off')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
input_batch = x.reshape((1,*x.shape))
print(input_batch.shape)
# Out:
# (1, 200, 200, 3)

# %%
i = 0
for output_batch in datagen.flow(input_batch,batch_size=1):
    plt.figure()
    imgplot=plt.imshow(image.img_to_array(output_batch[0]))
    i+=1
    if i==40:
        break
    plt.show()

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history1 = model.fit(train_images, train_labels, batch_size=128, epochs=60, validation_split = 0.2)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
train_loss, train_acc = model.evaluate(train_images, train_labels, verbose=2)
print("Test accuracy: ", test_acc)
print("train accuracy: ", train_acc)
model.save("model.h6")
# Out:
# Train on 140 samples, validate on 36 samples
# Epoch 1/60
# 140/140 [==============================] - 3s 18ms/sample - loss: 0.4505 - accuracy: 0.8429 - val_loss: 2.8075 - val_accuracy: 0.0833
# Epoch 2/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.6773 - accuracy: 0.7143 - val_loss: 2.7939 - val_accuracy: 0.4444
# Epoch 3/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.8476 - accuracy: 0.6857 - val_loss: 2.5874 - val_accuracy: 0.4722
# Epoch 4/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.8428 - accuracy: 0.6857 - val_loss: 1.8283 - val_accuracy: 0.4722
# Epoch 5/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.5136 - accuracy: 0.8500 - val_loss: 1.5069 - val_accuracy: 0.4167
# Epoch 6/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.5001 - accuracy: 0.8500 - val_loss: 1.3156 - val_accuracy: 0.5278
# Epoch 7/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.5317 - accuracy: 0.8643 - val_loss: 1.2721 - val_accuracy: 0.4722
# Epoch 8/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.5426 - accuracy: 0.8500 - val_loss: 1.2106 - val_accuracy: 0.5000
# Epoch 9/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.4804 - accuracy: 0.8429 - val_loss: 1.2386 - val_accuracy: 0.4167
# Epoch 10/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.4399 - accuracy: 0.8429 - val_loss: 1.3642 - val_accuracy: 0.4722
# Epoch 11/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.4015 - accuracy: 0.8643 - val_loss: 1.5227 - val_accuracy: 0.5000
# Epoch 12/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.3695 - accuracy: 0.8929 - val_loss: 1.5696 - val_accuracy: 0.5556
# Epoch 13/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.3238 - accuracy: 0.9000 - val_loss: 1.5393 - val_accuracy: 0.4722
# Epoch 14/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.2876 - accuracy: 0.8929 - val_loss: 1.5365 - val_accuracy: 0.4722
# Epoch 15/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.2497 - accuracy: 0.9143 - val_loss: 1.5553 - val_accuracy: 0.4722
# Epoch 16/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.2109 - accuracy: 0.9357 - val_loss: 1.5960 - val_accuracy: 0.3611
# Epoch 17/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.2013 - accuracy: 0.9071 - val_loss: 1.6049 - val_accuracy: 0.4722
# Epoch 18/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1687 - accuracy: 0.9429 - val_loss: 2.0457 - val_accuracy: 0.4444
# Epoch 19/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1743 - accuracy: 0.9357 - val_loss: 2.4309 - val_accuracy: 0.4167
# Epoch 20/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1564 - accuracy: 0.9571 - val_loss: 2.2382 - val_accuracy: 0.4444
# Epoch 21/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1239 - accuracy: 0.9714 - val_loss: 2.0400 - val_accuracy: 0.5000
# Epoch 22/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1081 - accuracy: 0.9786 - val_loss: 1.8689 - val_accuracy: 0.5278
# Epoch 23/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0979 - accuracy: 0.9571 - val_loss: 1.8747 - val_accuracy: 0.5000
# Epoch 24/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1107 - accuracy: 0.9500 - val_loss: 1.9886 - val_accuracy: 0.5000
# Epoch 25/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0756 - accuracy: 0.9857 - val_loss: 2.3027 - val_accuracy: 0.4167
# Epoch 26/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0846 - accuracy: 0.9643 - val_loss: 2.3714 - val_accuracy: 0.3333
# Epoch 27/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0789 - accuracy: 0.9643 - val_loss: 1.9712 - val_accuracy: 0.5000
# Epoch 28/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0540 - accuracy: 0.9857 - val_loss: 1.8494 - val_accuracy: 0.5000
# Epoch 29/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0518 - accuracy: 0.9786 - val_loss: 2.0196 - val_accuracy: 0.4444
# Epoch 30/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0467 - accuracy: 0.9786 - val_loss: 2.2885 - val_accuracy: 0.4444
# Epoch 31/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0423 - accuracy: 0.9857 - val_loss: 2.7617 - val_accuracy: 0.4444
# Epoch 32/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0413 - accuracy: 1.0000 - val_loss: 3.1723 - val_accuracy: 0.3333
# Epoch 33/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0452 - accuracy: 0.9857 - val_loss: 3.0369 - val_accuracy: 0.3333
# Epoch 34/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0413 - accuracy: 0.9929 - val_loss: 2.6975 - val_accuracy: 0.4444
# Epoch 35/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0329 - accuracy: 1.0000 - val_loss: 2.3656 - val_accuracy: 0.5000
# Epoch 36/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0539 - accuracy: 0.9714 - val_loss: 4.6848 - val_accuracy: 0.3333
# Epoch 37/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0800 - accuracy: 0.9786 - val_loss: 6.5592 - val_accuracy: 0.1389
# Epoch 38/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.3252 - accuracy: 0.8786 - val_loss: 4.5221 - val_accuracy: 0.4167
# Epoch 39/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.2545 - accuracy: 0.9000 - val_loss: 2.9566 - val_accuracy: 0.5556
# Epoch 40/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0900 - accuracy: 0.9643 - val_loss: 2.2767 - val_accuracy: 0.5000
# Epoch 41/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1154 - accuracy: 0.9571 - val_loss: 1.9330 - val_accuracy: 0.5000
# Epoch 42/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.1196 - accuracy: 0.9429 - val_loss: 1.6528 - val_accuracy: 0.5556
# Epoch 43/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0930 - accuracy: 0.9643 - val_loss: 1.6158 - val_accuracy: 0.5833
# Epoch 44/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0856 - accuracy: 0.9857 - val_loss: 1.6825 - val_accuracy: 0.4167
# Epoch 45/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0883 - accuracy: 0.9929 - val_loss: 1.7072 - val_accuracy: 0.3611
# Epoch 46/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0881 - accuracy: 0.9857 - val_loss: 1.6026 - val_accuracy: 0.3333
# Epoch 47/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0746 - accuracy: 0.9929 - val_loss: 1.6137 - val_accuracy: 0.5278
# Epoch 48/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0565 - accuracy: 1.0000 - val_loss: 2.0079 - val_accuracy: 0.5000
# Epoch 49/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0538 - accuracy: 0.9857 - val_loss: 2.4898 - val_accuracy: 0.5000
# Epoch 50/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0685 - accuracy: 0.9786 - val_loss: 2.1094 - val_accuracy: 0.4444
# Epoch 51/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0426 - accuracy: 0.9786 - val_loss: 2.5456 - val_accuracy: 0.2778
# Epoch 52/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0681 - accuracy: 0.9857 - val_loss: 2.8945 - val_accuracy: 0.2222
# Epoch 53/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0557 - accuracy: 0.9929 - val_loss: 3.4713 - val_accuracy: 0.2222
# Epoch 54/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0859 - accuracy: 0.9714 - val_loss: 2.5574 - val_accuracy: 0.5000
# Epoch 55/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0559 - accuracy: 0.9857 - val_loss: 2.0146 - val_accuracy: 0.5278
# Epoch 56/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0675 - accuracy: 0.9714 - val_loss: 2.2648 - val_accuracy: 0.4444
# Epoch 57/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0426 - accuracy: 0.9857 - val_loss: 2.5779 - val_accuracy: 0.3611
# Epoch 58/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0459 - accuracy: 0.9929 - val_loss: 2.7244 - val_accuracy: 0.5000
# Epoch 59/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0296 - accuracy: 1.0000 - val_loss: 3.0718 - val_accuracy: 0.2778
# Epoch 60/60
# 140/140 [==============================] - 1s 9ms/sample - loss: 0.0362 - accuracy: 0.9857 - val_loss: 3.3110 - val_accuracy: 0.3333
# 64/64 - 0s - loss: 2.4098 - accuracy: 0.5156
# 176/176 - 0s - loss: 0.7094 - accuracy: 0.8523
# Test accuracy:  0.515625
# train accuracy:  0.85227275
# WARNING:tensorflow:From C:\Users\parit\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: model.h6\assets

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)
